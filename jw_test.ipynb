# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append("../")
sys.path.append("../..")

start='2020-09-30 00:00:01'
end ='2020-10-18 00:00:00'
from data_selection import static_dataSet 
from KETI_pre_dataIngestion.data_influx import ingestion_partial_dataset as ipd
from KETI_pre_dataIngestion.KETI_setting import influx_setting_KETI as ins
# data selection
intDataInfo = static_dataSet.set_integratedDataInfo(start, end)
# data ingestion
data_raw_partial = ipd.partial_dataSet_ingestion(intDataInfo, ins)
# Out:
# {'db_name': 'INNER_AIR', 'measurement': 'HS1', 'domain': 'farm', 'subdomain': 'airQuality', 'start': '2020-09-30 00:00:01', 'end': '2020-10-18 00:00:00'}
# {'db_name': 'OUTDOOR_AIR', 'measurement': 'sangju', 'domain': 'city', 'subdomain': 'airQuality', 'start': '2020-09-30 00:00:01', 'end': '2020-10-18 00:00:00'}
# {'db_name': 'OUTDOOR_WEATHER', 'measurement': 'sangju', 'domain': 'city', 'subdomain': 'weather', 'start': '2020-09-30 00:00:01', 'end': '2020-10-18 00:00:00'}

# %%
from KETI_pre_dataCleaning.data_validation import valid_data as vdt
valid = vdt.valid_data()
data_previous = data_raw_partial[0]
data_previous['CO2ppm'].plot()
plt.show()
data_valid = valid.data_validation(data_raw_partial[0])
data_valid['CO2ppm'].plot()
plt.show()
